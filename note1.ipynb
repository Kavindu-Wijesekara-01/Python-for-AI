# %%
print("hello",1,2,True,sep="-")
# Out:
# hello-1-2-True

# %%
print("kavindu", end="*")
print("gayantha")
# Out:
# kavindu*gayantha

# %%
print("kavindu", end=" ")
print("gayantha")
# Out:
# kavindu gayantha

# %%
print("kavindu")
print("gayantha")
# Out:
# kavindu
# gayantha

# %% [markdown]
# ## single line comments

# %%
# single line comment

# %% [markdown]
# ## multi line comments

# %%
"""
This is a multiline string
jhjhgjgj
jhgjgjgjhj
"""
print("no output")
# Out:
# no output

# %% [markdown]
# # Data Types

# %%
type("kavindu")
# Out:
# str

# %%
type(35)
# Out:
# int

# %%
print(5.56)
type(5.56)
# Out:
# 5.56
# float

# %%
type(True)
# Out:
# bool

# %%
type(5-7j)
# Out:
# complex

# %%
# list

print([1,2,3])
# Out:
# [1, 2, 3]

# %%
type([1,2.3])
# Out:
# list

# %%
# tuple

print((1,2,3))
# Out:
# (1, 2, 3)

# %%
type((1,2,3))
# Out:
# tuple

# %%
# sets

print({1,2,3})

type({1,2,3})
# Out:
# {1, 2, 3}
# set

# %%
# dictionary

print({"Name":"Kavindu", "Age":25, "gender":"male"})

type({"Name":"Kavindu", "Age":25, "gender":"male"})
# Out:
# {'Name': 'Kavindu', 'Age': 25, 'gender': 'male'}
# dict

# %% [markdown]
# # Variables

# %%
a=3
print(a)
# Out:
# 3

# %%
b=3.4
print(b)
# Out:
# 3.4

# %%
c=True
e="True"
d="kavindu"
print(c,e,d)
print(d)
print(e)
# Out:
# True True kavindu
# kavindu
# True

# %%
name = "Kavindu"
print("welcome", name)
# Out:
# welcome Kavindu

# %%
a=2
b=5
print(a+b)
# Out:
# 7

# %% [markdown]
# ### dynamic typing
#
# a = 9  (int type)
#
# ### static typing
#
# int b = 7 ( c,c++,java )

# %% [markdown]
# ### dynamic binding

# %%
a=4
print(a)
a="kavindu"
print(a)
# Out:
# 4
# kavindu

# %% [markdown]
# ### static binding

# %% [markdown]
# int a = 7
# int a = "kavindu"

# %%
a,b,c = 1,2,3
print(a,b,c)

a=b=c=6
print(a,b,c)
# Out:
# 1 2 3
# 6 6 6
