# %% [markdown]
# # Strings

# %%
"""my name is kavindu
i am from sri lanbka
"""
# Out:
# 'my name is kavindu\ni am from sri lanbka\n'

# %%
a = 5
str(a)
# Out:
# '5'

# %%
s= "sri lanka"
print(s[4])
print(s[-2])
# Out:
# l
# k

# %%
print(len(s))
# Out:
# 9

# %%
a = "hello sri lanka"
print(a[0:5])
# Out:
# hell

# %%
print(a[6:])
print(a[:5])
# Out:
# sri lanka
# hello

# %%
print(a[0:7:2])
print(a[7:1:-2])
print(a[::-1])
print(a[-1:-5:-1])
print(s[-5:-1])
# Out:
# hlos
# r l
# aknal irs olleh
# akna
# lank

# %% [markdown]
# ### strings can not any aditing

# %%
print("hi"+" "+"kavindu")
# Out:
# hi kavindu

# %%
print("*"*5)
# Out:
# *****

# %%
"kavindu">"dog"
# Out:
# True

# %%
"ball"=="ball"
# Out:
# True

# %%
"ball">"cat"
# Out:
# False

# %%
"kavindu" and "gayantha"

# empty string mean value 0 and other string value 1 
# so "kavindu" = 1 and "gayantha" = 1 then output last thing
# Out:
# 'gayantha'

# %%
"kavindu" or "gayantha"

# here first one is true then output will be first element. beacause or gate
# Out:
# 'kavindu'

# %%
"" or "gayantha"
# Out:
# 'gayantha'

# %%
not "hello" 
# not hello mean hello string convert into empty string
# Out:
# False

# %%
for i in "kavindu":
    print(i, end=" ")
# Out:
# k a v i n d u

# %%
for i in "kavindu":
    print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
"k" in "kavindu"
# Out:
# True

# %%
"w" not in "kavindu"
# Out:
# True
