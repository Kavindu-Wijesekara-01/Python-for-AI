# %% [markdown]
# ## Builtins modules

# %% [markdown]
# ### math

# %%
import math

int(math.sqrt(24))
# Out:
# 4

# %%
math.sqrt(24)
# Out:
# 4.898979485566356

# %%
math.factorial(5)
# Out:
# 120

# %% [markdown]
# ### keyword

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### random

# %%
import random
print(random.randint(1,500))
# Out:
# 120

# %% [markdown]
# ### datetime

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2026-04-26 08:30:47.201619

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# Database not initialized by migration_upgrade(). Running it again
# c:\Users\LENOVO\anaconda3\Lib\site-packages\conda_pack\core.py:16: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# c:\Users\LENOVO\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning:
#
# The twython library has not been installed. Some functionality from the twitter package will not be available.
#
# c:\Users\LENOVO\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# IPython             cachetools          mako                shlex
# OpenSSL             calendar            markdown            shutil
# ...
