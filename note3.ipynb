# %%
email = input("enter email address: ")
password = input("enter password: ")

if email == "kavinduwijesekara12@gmail.com" and password == "1234":
    print("login successful")
elif email == "kavinduwijesekara12@gmail.com" and password != "1234":
    print("please try again")
else:
    print("invalid credentials!")
# Out:
# successful

# %%
email = input("enter email address: ")
password = input("enter password: ")

if email == "kavinduwijesekara12@gmail.com" and password == "1234":
    print("login successful")

elif email == "kavinduwijesekara12@gmail.com" and password != "1234":
    password = input("enter correct password: ")
    if password == "1234":
        print("login successful")
    else:
        print("wrong!")
else:
    print("invalid credentials!")
# Out:
# login successful
