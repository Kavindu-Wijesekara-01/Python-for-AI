# %%
a = "hello kavindu"

# %%
len(a)
# Out:
# 13

# %%
max(a) #asci
# Out:
# 'v'

# %%
min(a)
# Out:
# ' '

# %%
sorted(a)
# Out:
# [' ', 'a', 'd', 'e', 'h', 'i', 'k', 'l', 'l', 'n', 'o', 'u', 'v']

# %%
a = "hello world"
sorted(a)
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %%
a = "hello world"
sorted(a, reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# ## string function methord

# %%
# capitalize

s="kavindu gayantha wijesekara"
s.capitalize()
# Out:
# 'Kavindu gayantha wijesekara'

# %%
s.title()
# Out:
# 'Kavindu Gayantha Wijesekara'

# %%
s.upper()
# Out:
# 'KAVINDU GAYANTHA WIJESEKARA'

# %%
s.lower()
# Out:
# 'kavindu gayantha wijesekara'

# %%
s = "mahARAGAma hOMAGmAGAM"
s.swapcase()
# Out:
# 'MAHaragaMA HomagMagam'

# %%
m = "my name is kavindu"

# %%
m.count("k")
# Out:
# 1

# %%
m.find("a")
# Out:
# 4

# %%
m.index("k")
# Out:
# 11

# %%
o = "kavindu gayanatha"

# %%
o.endswith("tha")
# Out:
# True

# %%
o.startswith("Kav")
# Out:
# False

# %%
name  = "kavindu"
gender = "male"

v = "my name is {}, and i am a {}"

# %%
v.format(name, gender)
# Out:
# 'my name is kavindu, and i am a male'

# %%
name  = "kavindu"
gender = "male"

v = "my name is {1}, and i am a {0}"

# %%
v.format(gender, name)
# Out:
# 'my name is kavindu, and i am a male'

# %%
k = "welcome {} to facebook"
name = "dulmi"

# %%
k.format(name)
# Out:
# 'welcome dulmi to facebook'

# %%
s = "kavindu456"

# %%
s.isalnum()
# Out:
# False

# %%
s="kavindu"

# %%
s.isalpha()
# Out:
# True

# %%
s = "12"

# %%
s.isdigit()
# Out:
# True

# %%
s ="_name"
s.isidentifier()
# Out:
# True

# %%
s = "my name is kavindu"

# %%
s.split() # covert to list
# Out:
# ['my', 'name', 'is', 'kavindu']

# %%
a = "my, name, is, kavindu"

# %%
a.split(",")
# Out:
# ['my', ' name', ' is', ' kavindu']

# %%
words = ['my', ' name', ' is', ' kavindu']

# %%
a = "-"
a = a.join(words)
print(a)
# Out:
# my- name- is- kavindu

# %%
s = "my name is kavindu"

# %%
s.replace("kavindu", "gayanatha")
# Out:
# 'hello world       '

# %%
s = "hello world       "

# %%
len(s)
# Out:
# 18

# %%
s = s.strip()

# %%
print(s)
# Out:
# hello world

# %%
len(s)
# Out:
# 11

# %%
s = "my name is {}. i am a {}"

name = "kavindu" 
gender = "male"

print(s.format(name, gender))
# Out:
# my name is kavindu. i am a male

# %%
name = "kavindu"
gender = "male"

s = f"my name is {name}. i am a {gender}"
print(s)
# Out:
# my name is kavindu. i am a male

# %%
email = input("enter your email: ")
pos = email.index("@")

print(pos)
print(email[0:pos])
# Out:
# 17
# kavinduwijesekara

# %%
word = input("input your word")
flag = True
for i in range(0, len(word)//2):
    if word[i] != word[len(word)-i-1]:
        flag=False
        print("not")
        break

if flag:
    print("yes")
# Out:
# not
