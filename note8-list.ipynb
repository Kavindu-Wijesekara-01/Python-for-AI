# %% [markdown]
# # List

# %%
l1 = [1,2,3]
l2 = [3,1,2]

l1 == l2
# Out:
# False

# %%
l1 = [1,2,5,[5,3]]
print(l1[3][0])
# Out:
# 5

# %%
l1 = [[[5,6.56],["k",5,2.5]],[5.,56.5]]

# %%
len(l1)
# Out:
# 2

# %%
print(l1[0][1])
# Out:
# ['k', 5, 2.5]

# %%
print(l1[0][1][1:])
# Out:
# [5, 2.5]

# %%
# append
l = [1,2,3,5]
l.append(8)
print(l)
# Out:
# [1, 2, 3, 5, 8]

# %%
# edditing with indexing

l[0] = 6
print(l)
# Out:
# [6, 2, 3, 5, 8]

# %%
# editing with slicing

l[1:] = [200,300,500]
print(l)
# Out:
# [6, 200, 300, 500]

# %%
l.append([80,60,75])
print(l)
# Out:
# [6, 200, 300, 500, [80, 60, 75], [80, 60, 75], [80, 60, 75], [80, 60, 75]]

# %%
l.append(True)
print(l)
# Out:
# [6, 200, 300, 500, [80, 60, 75], [80, 60, 75], [80, 60, 75], [80, 60, 75], True, True]

# %%
x = [2,5,8]
y = [1,4,7]
x.extend(y)
print(x)
# Out:
# [2, 5, 8, 1, 4, 7]

# %%
y.extend("HELLO")
print(y)
# Out:
# [1, 4, 7, 'H', 'E', 'L', 'L', 'O']

# %%
# insert

l = [1,2,3,5]
l.insert(2,300)
print(l)
# Out:
# [1, 2, 300, 3, 5]

# %%
l = [1,2,3,5]
del l[2]
print(l)
# Out:
# [1, 2, 5]

# %%
l = [1,2,3,5]
l.remove(5)
print(l)
# Out:
# [1, 2, 3]

# %%
l = [1,2,3,5]
l.pop()
print(l)
# Out:
# [1, 2, 3]

# %%
l = [1,2,3,5]
l.clear()
print(l)
# Out:
# []

# %%
l = [1,2,3,5]
print(len(l))
print(max(l))
print(sorted(l, reverse=True))
# Out:
# 4
# 5
# [5, 3, 2, 1]

# %%
a = [1,2,5,4,2,3,5,2,8,2]
a.count(2)
# Out:
# 4

# %%
a.index(1)
# Out:
# 0

# %%
a.reverse()
print(a)
# Out:
# [2, 8, 2, 5, 3, 2, 4, 5, 2, 1]

# %%
a.sort()
print(a)
# Out:
# [1, 2, 2, 2, 2, 3, 4, 5, 5, 8]

# %%
a1 = a.copy()
print(a1)
# Out:
# [1, 2, 2, 2, 2, 3, 4, 5, 5, 8]

# %%
a.append(200)
print(a)
# Out:
# [1, 2, 2, 2, 2, 3, 4, 5, 5, 8, 200]

# %%
print(a1)
# Out:
# [1, 2, 2, 2, 2, 3, 4, 5, 5, 8]

# %%
id(a)
# Out:
# 2448641491328

# %%
id(a1)
# Out:
# 2448641383616
