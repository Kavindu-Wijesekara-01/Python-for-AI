# %% [markdown]
# ## sets

# %%
s = set()
print(s)
print(type(s))
# Out:
# set()
# <class 'set'>

# %%
s1 = {1,2,5}
print(s1)
# Out:
# {1, 2, 5}

# %%
# set is mutable.can not insert nested list
s2 = {1,2,4,{8,6}}
print(s2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s2 = {1,2,4,{8,6}}
#       2 print(s2)
#
# TypeError: unhashable type: 'set'

# %%
# hetro
s3 = {1,'hello',8.5,(5,8)}
print(s3)
# Out:
# {'hello', 1, 8.5, (5, 8)}

# %%
s4 = set([1,2,3])
print(s4)
# Out:
# {1, 2, 3}

# %%
# dublicate not allow

s5 = {1,1,2,2,3,3,3}
print(s5)
# Out:
# {1, 2, 3}

# %%
# set can not have mutable item

s3 = {1,2,5,[8,6]}
print(s3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # set can not have mutable item
# ----> 3 s3 = {1,2,5,[8,6]}
#       4 print(s3)
#
# TypeError: unhashable type: 'list'

# %%
s1 = {1,2,3}
s2 = {3,2,1}

s1 == s2
# Out:
# True

# %%
s1 = {1,2,3}
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 s1 = {1,2,3}
# ----> 2 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s3 = {1,'hello',4.5,(1,2,3)}
print(s3)
# Out:
# {'hello', 1, (1, 2, 3), 4.5}

# %%
s3[0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s3[0:2]
#
# TypeError: 'set' object is not subscriptable

# %%
s1 = {1,2,3}

s[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 s1 = {1,2,3}
# ----> 2 s[1] = 100
#
# TypeError: 'set' object does not support item assignment

# %%
s1 = {1,2,3}
s1.add(5)
s1
# Out:
# {1, 2, 3, 5}

# %%
s1.update([11,12,13])
print(s1)
# Out:
# {1, 2, 3, 5, 11, 12, 13}

# %%
del s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 del s[0]
#
# TypeError: 'set' object doesn't support item deletion

# %%
s1.discard(12)
s1
# Out:
# {1, 2, 3, 5, 11, 13}

# %%
s1.discard(25)
s1
# Out:
# set()

# %%
s1.remove(13)
s1
# Out:
# {1, 2, 3, 5, 11}

# %%
s1.remove(85)

s1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s1.remove(85)
#       3 s1
#
# KeyError: 85

# %%
# randomly delete

s1.pop()
s1
# Out:
# {2, 3, 5, 11}

# %%
s1.clear()
s1
# Out:
# set()
